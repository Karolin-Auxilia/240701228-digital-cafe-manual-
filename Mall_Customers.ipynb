# %% [markdown]
# <a href="https://colab.research.google.com/github/Karolin-Auxilia/240701228-digital-cafe-manual-/blob/main/Mall_Customers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df = pd.read_csv("house_price.csv")
print("Dataset:\n", df)
X = df[['SquareFeet', 'Bedrooms', 'Bathrooms']]
y = df['Price']
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)
print("\nModel Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
print("\nPredicted Prices:\n", y_pred)
plt.figure(figsize=(5,4))
plt.scatter(df['SquareFeet'], y, color='blue', label='Actual Price')
plt.scatter(df['SquareFeet'], y_pred, color='red', label='Predicted Price')
plt.xlabel("Square Feet")
plt.ylabel("House Price")
plt.title("House Price Prediction")
plt.legend()
plt.show()
# Out:
# Dataset:
#     SquareFeet  Bedrooms  Bathrooms   Price
# 0        1500         3          2  300000
# 1        2000         4          3  400000
# 2        2500         4          2  500000
# 3        3000         5          4  600000
# 4        3500         5          4  700000
# 5        4000         2          1  200000
# 6        1200         3          2  420000
# 7        2200         4          3  550000
# 8        2800         5          4  650000
# 9        3200         4          5  700000
#
# Model Coefficients: [6.54545199e+00 7.14730605e+04 7.64556304e+04]
# Intercept: -23064.547870544367
#
# Predicted Prices:
#  [354084.07247544 505285.48938006 432102.58500721 659759.63227969
#  663032.3582747  222519.01154091 352120.43687843 506594.57977806
#  658450.54188168 666051.29250381]
